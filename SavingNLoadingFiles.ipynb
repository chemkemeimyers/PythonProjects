# %% [markdown]
# <a href="https://colab.research.google.com/github/chemkemeimyers/PythonProjects/blob/main/SavingNLoadingFiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path = '/content/drive/MyDrive/MachineLearningCourse/Python/StockData.csv'
data=pd.read_csv(path)

# %%
data.head()
# Out:
#   stock        date    price
# 0  AAPL  08-02-2013  67.8542
# 1  AAPL  11-02-2013  68.5614
# 2  AAPL  12-02-2013  66.8428
# 3  AAPL  13-02-2013  66.7156
# 4  AAPL  14-02-2013  66.6556

# %%
path_excel = '/content/drive/MyDrive/MachineLearningCourse/Python/StockData.xlsx'
data_excel = pd.read_excel(path_excel)

# %%
data_excel.head()
# Out:
#   stock       date    price
# 0  AAPL 2013-02-08  67.8542
# 1  AAPL 2013-02-11  68.5614
# 2  AAPL 2013-02-12  66.8428
# 3  AAPL 2013-02-13  66.7156
# 4  AAPL 2013-02-14  66.6556

# %%
data.to_csv('/content/drive/MyDrive/MachineLearningCourse/Python/Saved_StockData.csv', index=False)

# %%
data.to_excel('/content/drive/MyDrive/MachineLearningCourse/Python/Saved_StockData.xlsx')
